# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1>DENGUE DATA ANALYSIS</h1>
# <h2>INCLUSIVE YEAR 2016 - 2020</h2>
# <h3>Analyst: James Patrick I. De Mesa</h3>

# %%
dengue = pd.read_csv("datasets\\dengue.csv")

# %%
dengue
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %%
dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          1020 non-null   category
#  1   Year           1020 non-null   category
#  2   Region         1020 non-null   category
#  3   Dengue_Cases   1020 non-null   int64
#  4   Dengue_Deaths  1020 non-null   int64
# dtypes: category(3), int64(2)
# memory usage: 20.3 KB

# %%
dengue["Month"] = dengue["Month"].astype("category")
dengue["Year"] = dengue["Year"].astype("category")
dengue["Region"] = dengue["Region"].astype("category")

# %%
dengue.isnull().sum()
# Out:
# Month            0
# Year             0
# Region           0
# Dengue_Cases     0
# Dengue_Deaths    0
# dtype: int64

# %% [markdown]
# <h1>Insight No. 1</h1>
# <h3>In which region has the highest dengue cases?</h3>
# <h2 style="color:red">Region IV-A has the highest number of dengue case</h2>

# %%
sns.barplot(data=dengue, x = "Region", y = "Dengue_Cases")
plt.gcf().set_size_inches(17, 7)
plt.show()

# %% [markdown]
# <h1>Insight No. 2</h1>
# <h3>In which month has the highest dengue deaths?</h3>
# <h2 style="color:red">Month of October has the highest number of dengue deaths</h2>

# %%
order = dengue["Month"].unique()
sns.barplot(data=dengue, x = "Month", y = "Dengue_Deaths", order=order)
plt.gcf().set_size_inches(14, 7)
plt.show()

# %% [markdown]
# <h1>Insight No. 2</h1>
# <h3>In which year has the highest dengue cases?</h3>
# <h2 style="color:red">Year 2019 has the highest number of dengue case</h2>

# %%
sns.barplot(data=dengue, x="Year", y="Dengue_Cases")
plt.gcf().set_size_inches(14, 7)
plt.show()
