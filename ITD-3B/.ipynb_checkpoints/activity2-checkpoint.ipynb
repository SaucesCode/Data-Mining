# %% [markdown]
# ## <h1>DATA MINING</h1>

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC14\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC14\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC14\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC14\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1>IMPORTING DATASET TO DATA FRAME</h1>

# %%
birds = pd.read_csv('datasets\\penguins.csv')

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h1>Descriptive Analytics</h1>

# %%
birds.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
birds.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %% [markdown]
# <h2>FILTERING DATA BASED FROM COLUMNS</h2>

# %%
birds['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
birds['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3         NaN
# 4      female
#         ...
# 339      male
# 340    female
# 341      male
# 342      male
# 343    female
# Name: sex, Length: 344, dtype: object

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000, 1)

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007     3.8
# 1                186.0       3800.0  female  2007     3.8
# ...

# %% [markdown]
# <h1> WHAT TO DO WITH NULL VALUES</h1>

# %%
birds['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
birds['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'].mean())
birds['bill_depth_mm'] = birds['bill_depth_mm'].fillna(birds['bill_depth_mm'].mean())
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'].mean())
birds['body_mass_g'] = birds['body_mass_g'].fillna(birds['body_mass_g'].mean())
birds['weight'] = birds['weight'].fillna(birds['weight'].mean())
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    object
#  8   year               344 non-null    int64
#  9   weight             344 non-null    float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 27.0+ KB

# %%
birds['year'] = birds['year'].astype('category')
birds['rowid'] = birds['rowid'].astype('category')
birds['species'] = birds['species'].astype('category')
birds['island'] = birds['island'].astype('category')
birds['sex'] = birds['sex'].astype('category')

# %%
birds
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.800000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
birds[birds['species'] == 'Adelie'].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       152
# bill_depth_mm        152
# flipper_length_mm    152
# body_mass_g          152
# sex                  152
# year                 152
# weight               152
# dtype: int64

# %%
birds[birds['species'] == 'Chinstrap'].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight               68
# dtype: int64

# %%
birds[birds['species'] == 'Gentoo'].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight               124
# dtype: int64

# %%
birds[birds['species'] == 'Gentoo']
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %%
birds
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.800000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
birds[(birds['species'] == "Gentoo") & (birds['body_mass_g'] > 3000)]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %% [markdown]
# <h1>Is Gentoo exclusive to one island?</h1>
# <h1 style="color:red">Insight No. 1</h1>
# <h2 style="color:blue">Gentoo is exclusive to one island. It is Biscoe Island</h2>

# %%
gentoo_dream = birds[(birds['species'] == "Gentoo") & (birds['island'] == "Dream")]

# %%
gentoo_tor = birds[(birds['species'] == "Gentoo") & (birds['island'] == "Torgersen")]

# %%
gentoo_biscoe = birds[(birds['species'] == "Gentoo") & (birds['island'] == "Biscoe")]

# %% [markdown]
# <h1>Is Chinstrap exclusive to one island?</h1>
# <h1 style="color:red">Insight No. 2</h1>
# <h2 style="color:blue">Chinstrap is exclusive to one island. It is Dream Island</h2>

# %%
chinstrap_biscoe = birds[(birds['species'] == "Chinstrap") & (birds['island'] == "Biscoe")]

# %%
chinstrap_dream = birds[(birds['species'] == "Chinstrap") & (birds['island'] == "Dream")]

# %%
chinstrap_tor = birds[(birds['species'] == "Chinstrap") & (birds['island'] == "Torgersen")]

# %% [markdown]
# <h1>Is Adelie exclusive to one island?</h1>
# <h1 style="color:red">Insight No. 3</h1>
# <h2 style="color:blue">Adelie is not exclusive to one island. Adelie lives in all 3 island</h2>

# %%
adelie_biscoe = birds[(birds['species'] == "Adelie") & (birds['island'] == "Biscoe")]

# %%
adelie_dream = birds[(birds['species'] == "Adelie") & (birds['island'] == "Dream")]

# %%
adelie_tor = birds[(birds['species'] == "Adelie") & (birds['island'] == "Torgersen")]

# %% [markdown]
# <h1 >Does the island affects the weight?</h1>

# %%
aveW_adelie_dream = np.round(adelie_dream['weight'].mean(), 1)

# %%
aveW_adelie_dream
# Out:
# np.float64(3.7)

# %%
aveW_adelie_tor = np.round(adelie_tor['weight'].mean(), 1)

# %%
aveW_adelie_tor
# Out:
# np.float64(3.7)

# %%
aveW_adelie_biscoe = np.round(adelie_biscoe['weight'].mean(), 1)

# %%
aveW_adelie_biscoe
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1 style="color:red">Insight No. 4</h1>
# <h2 style="color:blue">The island doesn't affect the weight of the Adelie species</h2>

# %% [markdown]
# <h1>What is the average weight of gentoo</h1>
# <h1 style="color:red">Insight No. 5</h1>
# <h2 style="color:blue">The average weight of gentoo species is 5.1kg</h2>

# %%
aveW_gentoo_biscoe = np.round(gentoo_biscoe['weight'].mean(), 1)

# %%
aveW_gentoo_biscoe
# Out:
# np.float64(5.1)

# %% [markdown]
# <h1>What is the average weight of Chinstrap?</h1>
# <h1 style="color:red">Insight No. 6</h1>
# <h2 style="color:blue">The average weight of chinstrap species is 3.7kg</h2>

# %%
aveW_chinstrap_dream= np.round(chinstrap_dream['weight'].mean(), 1)

# %%
aveW_chinstrap_dream
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1>What is the heaviest penguin?</h1>

# %% [markdown]
# <h1 style="color:red">Insight No. 7</h1>
# <h1 style="color:blue">The heaviest species of penguin is the Gentoo</h1>
# <h2>The heaviest is the Gentoo species with 5.1kg</h2>

# %% [markdown]
# <h1 style="color:red">Insight No. 8</h1>
# <h2 style="color:blue">What species has the highest recorded male?</h2>

# %%
birds_male = birds.groupby(["species", "island", "year", "sex"]).size()
# Out:
# C:\Users\LAB4-StudentPC14\AppData\Local\Temp\ipykernel_12604\1075665052.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_male = birds.groupby(["species", "island", "year", "sex"]).size()

# %%
birds_male.unstack()
# Out:
# sex                       female  male
# species   island    year
# Adelie    Biscoe    2007       5     5
#                     2008       9     9
#                     2009       8     8
#           Dream     2007       9    11
#                     2008       8     8
#                     2009      10    10
#           Torgersen 2007       8    12
#                     2008       8     8
#                     2009       8     8
# Chinstrap Biscoe    2007       0     0
#                     2008       0     0
#                     2009       0     0
#           Dream     2007      13    13
#                     2008       9     9
#                     2009      12    12
#           Torgersen 2007       0     0
#                     2008       0     0
#                     2009       0     0
# Gentoo    Biscoe    2007      16    18
#                     2008      22    24
#                     2009      20    24
#           Dream     2007       0     0
# ...

# %% [markdown]
# <h1 style="color:red">Insight No. 9</h1>
# <h2 style="color:blue">Which sex is heavier in Adelie Species?</h2>
# <h3>The male is heavier</h3>

# %%
adelie_sex_weight = np.round(birds.groupby(["species", "sex"])["weight"].mean(), 1)
# Out:
# C:\Users\LAB4-StudentPC14\AppData\Local\Temp\ipykernel_12604\2526165962.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adelie_sex_weight = np.round(birds.groupby(["species", "sex"])["weight"].mean(), 1)

# %%
adelie_sex_weight
# Out:
# species    sex
# Adelie     female    3.4
#            male      4.0
# Chinstrap  female    3.5
#            male      3.9
# Gentoo     female    4.7
#            male      5.4
# Name: weight, dtype: float64

# %% [markdown]
# <h1 style="color:red">Insight No. 10</h1>
# <h2 style="color:blue">Which sex is heavier in Chinstrap Species?</h2>
# <h3>The male is heavier</h3>

# %%
chinstrap_sex_weight = np.round(birds.groupby(["species", "sex"])["weight"].mean(), 1)
# Out:
# C:\Users\LAB4-StudentPC14\AppData\Local\Temp\ipykernel_12604\121917576.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   chinstrap_sex_weight = np.round(birds.groupby(["species", "sex"])["weight"].mean(), 1)

# %%
chinstrap_sex_weight
# Out:
# species    sex
# Adelie     female    3.4
#            male      4.0
# Chinstrap  female    3.5
#            male      3.9
# Gentoo     female    4.7
#            male      5.4
# Name: weight, dtype: float64

# %% [markdown]
# <h1 style="color:red">Insight No. 11</h1>
# <h2 style="color:blue">Which sex is heavier in Gentoo Species?</h2>
# <h3>The male is heavier</h3>

# %%
gentoo_sex_weight = np.round(birds.groupby(["species", "sex"])["weight"].mean(), 1)
# Out:
# C:\Users\LAB4-StudentPC14\AppData\Local\Temp\ipykernel_12604\1644941135.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gentoo_sex_weight = np.round(birds.groupby(["species", "sex"])["weight"].mean(), 1)

# %%
gentoo_sex_weight
# Out:
# species    sex
# Adelie     female    3.4
#            male      4.0
# Chinstrap  female    3.5
#            male      3.9
# Gentoo     female    4.7
#            male      5.4
# Name: weight, dtype: float64

# %% [markdown]
# <h1 style="color:red">Insight No. 12</h1>
# <h2 style="color:blue">Does the bill length affects the bill depth?</h2>
# <h3>The bill length has no correlation with the bill depth</h3>

# %%
b_depth_length = birds['bill_length_mm'].corr(birds['bill_depth_mm'])

# %%
b_depth_length
# Out:
# np.float64(-0.23505287035553282)

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 26.9 KB

# %% [markdown]
# <h1 style="color:red">Insight No. 13</h1>
# <h2 style="color:blue">Does the weight affects the flipper length?</h2>
# <h3>The weight has a correlation with the flipper lenght</h3>

# %%
weight_flength = birds['weight'].corr(birds['flipper_length_mm'])

# %%
weight_flength
# Out:
# np.float64(0.8706550442461825)

# %% [markdown]
# <h1 style="color:red">Insight No. 14</h1>
# <h2 style="color:blue">Does the weight affects the bill length?</h2>
# <h3>The weight has a correlation with the bill lenght</h3>

# %%
weight_blength = birds['weight'].corr(birds['bill_length_mm'])

# %%
weight_blength
# Out:
# np.float64(0.5931909179206184)

# %% [markdown]
# <h1 style="color:red">Insight No. 15</h1>
# <h2 style="color:blue">Does the bill length affects the flipper length?</h2>
# <h3>The bill length has a correlation with the flipper length</h3>

# %%
blength_flength = birds['bill_length_mm'].corr(birds['flipper_length_mm'])

# %%
blength_flength
# Out:
# np.float64(0.6561813407464278)

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC14\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# <h1>One Way Annova</h1>

# %%
from scipy.stats import f_oneway

# %% [markdown]
# <h1 style="color:red">Insight No. 16</h1>
# <h2 style="color:blue">There is correlation between sex and weight</h2>

# %%
#FILTER THE COLUMNS AND DATA
m_weight = birds[birds['sex'] == 'male']['weight']
f_weight = birds[birds['sex'] == 'female']['weight']

f_stats, p_value = f_oneway(m_weight, f_weight)
print(p_value)
# Out:
# 2.5288724247849435e-15
